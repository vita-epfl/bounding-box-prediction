# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import import_ipynb
import DataLoader_P_speed
import utils
import time
import numpy as np
# Out:
# importing Jupyter notebook from DataLoader_P_speed.ipynb
# importing Jupyter notebook from utils.ipynb

# %%
class args():
    def __init__(self):
        self.base_out_features = 2048
        self.t_obs = 8
        self.batch_size = 20
        self.scene_shape = [3, 144, 256]
        self.base_shape = [2048, 9, 16]
        self.hidden_size = 128
        self.embedding_size = 64
        self.input_size = 2
        self.output_size = 2
        self.sample = True
        self.n_train_sequences = 15000
        self.n_val_sequences = 10
        self.trainOrVal = 'train'
        self.citywalks = False
        
        #dataset
        self.jaad_dataset = '../../../../data/smailait-data/jaad/annotations'
        self.dtype = 'train'
        self.from_file = True
        self.file = '/data/smailait-data/train_speed.csv'
        self.val_file = '/data/smailait-data/val_speed.csv'
        self.seq_len = 4
        self.predicted_seq_len = 4
        self.crop = 0.3
        self.activity_h = 9
        self.activity_w = 16
        self.truncate = 0
        self.final_frame_offset = 0
        self.loader_workers = 20
        self.loader_shuffle = True
        self.pin_memory = False
        self.image_resize = [144, 256]
        self.image_size = [1080, 1920]
        self.device='cuda'
        
args = args()

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        
        self.in_ = nn.Linear(in_features=4, out_features=128)
        self.hid1 = nn.Linear(in_features=128, out_features=256)
        self.hid2 = nn.Linear(in_features=256, out_features=128)
        self.out_ = nn.Linear(in_features=128, out_features=4)
        self.activation = nn.ReLU()
        
    def forward(self, input_):
        input_ = self.activation(self.in_(input_))
        input_ = self.activation(self.hid1(input_))
        input_ = self.activation(self.hid2(input_))
        output = self.activation(self.out_(input_))
        return output

# %%
net = MLP().to('cuda')

# %%
train, val, test = DataLoader_P_speed.data_loader(args)
# Out:
# frame
# crossing_true
# imagefolderpath
# scenefolderpath
# filename
# file
# bounding_box
# im_size
# future_bounding_box
# train  loaded
# frame
# crossing_true
# imagefolderpath
# scenefolderpath
# filename
# file
# bounding_box
# im_size
# future_bounding_box
# train  loaded
# frame
# crossing_true
# imagefolderpath
# scenefolderpath
# filename
# file
# bounding_box
# im_size
# future_bounding_box
# val  loaded

# %%
learning_rate = 0.001
optimizer = optim.Adam(net.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=10, threshold = 1e-4, verbose=True)
criterion = nn.MSELoss()
train_scores = []
val_scores = []

# %%
for epoch in range(100):
    avg_epoch_train_loss = 0
    avg_epoch_val_loss = 0
    ade = 0
    fde = 0
    aae = 0
    counter = 0
    for idx, (_, _, obs, target) in enumerate(train):
        counter += 1
        obs = obs.type(torch.float32).to(device='cuda')
        target = target.type(torch.float32).to(device='cuda')
        
        net.zero_grad()
        preds = net(obs)
        train_loss = criterion(preds, target)/(10000)
        train_loss.backward()
        optimizer.step()
        
        avg_epoch_train_loss += float(train_loss)
        
    avg_epoch_train_loss/=counter
    train_scores.append(avg_epoch_train_loss)

    print('e:', epoch, ' | train_loss: %.4f'% avg_epoch_train_loss, ' | val_loss: %.4f'% avg_epoch_val_loss)
# Out:
# e: 0  | train_loss: 0.7345  | val_loss: 0.0000
# e: 1  | train_loss: 0.2218  | val_loss: 0.0000
# e: 2  | train_loss: 0.2124  | val_loss: 0.0000
# e: 3  | train_loss: 0.2175  | val_loss: 0.0000
# e: 4  | train_loss: 0.2151  | val_loss: 0.0000
# e: 5  | train_loss: 0.2257  | val_loss: 0.0000
# e: 6  | train_loss: 0.2200  | val_loss: 0.0000
# e: 63  | train_loss: 0.1972  | val_loss: 0.0000
# e: 64  | train_loss: 0.1976  | val_loss: 0.0000
# e: 65  | train_loss: 0.1964  | val_loss: 0.0000
# e: 66  | train_loss: 0.1976  | val_loss: 0.0000
# e: 67  | train_loss: 0.1979  | val_loss: 0.0000
# e: 68  | train_loss: 0.1970  | val_loss: 0.0000
# e: 69  | train_loss: 0.1981  | val_loss: 0.0000
# e: 70  | train_loss: 0.1992  | val_loss: 0.0000
# e: 71  | train_loss: 0.1977  | val_loss: 0.0000
# e: 72  | train_loss: 0.1968  | val_loss: 0.0000
# e: 73  | train_loss: 0.1976  | val_loss: 0.0000
# e: 74  | train_loss: 0.1971  | val_loss: 0.0000
# e: 75  | train_loss: 0.1981  | val_loss: 0.0000
# e: 76  | train_loss: 0.1965  | val_loss: 0.0000
# e: 77  | train_loss: 0.1979  | val_loss: 0.0000
# e: 78  | train_loss: 0.1986  | val_loss: 0.0000
# e: 79  | train_loss: 0.1967  | val_loss: 0.0000
# e: 80  | train_loss: 0.1967  | val_loss: 0.0000
# e: 81  | train_loss: 0.1972  | val_loss: 0.0000
# e: 82  | train_loss: 0.1965  | val_loss: 0.0000
# e: 83  | train_loss: 0.1971  | val_loss: 0.0000
# e: 84  | train_loss: 0.1976  | val_loss: 0.0000
# e: 85  | train_loss: 0.1944  | val_loss: 0.0000
# e: 86  | train_loss: 0.1971  | val_loss: 0.0000
# e: 87  | train_loss: 0.1971  | val_loss: 0.0000
# e: 88  | train_loss: 0.1974  | val_loss: 0.0000
# e: 89  | train_loss: 0.1977  | val_loss: 0.0000
# e: 90  | train_loss: 0.1960  | val_loss: 0.0000
# e: 91  | train_loss: 0.1955  | val_loss: 0.0000
# e: 92  | train_loss: 0.1982  | val_loss: 0.0000
# e: 93  | train_loss: 0.1970  | val_loss: 0.0000
# e: 94  | train_loss: 0.1956  | val_loss: 0.0000
# e: 95  | train_loss: 0.1962  | val_loss: 0.0000
# e: 96  | train_loss: 0.1970  | val_loss: 0.0000
# e: 97  | train_loss: 0.1967  | val_loss: 0.0000
# e: 98  | train_loss: 0.1970  | val_loss: 0.0000
# e: 99  | train_loss: 0.1981  | val_loss: 0.0000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,20))
plt.plot(list(range(len(train_scores))), train_scores)
plt.plot(list(range(len(val_scores))), val_scores)
plt.show()

# %%
avg_epoch_val_loss = 0
ade = 0
fde = 0
aiou = 0
fiou = 0
counter=0
for idx, (_, _, obs, target) in enumerate(test):
    counter+=1
    obs = obs.type(torch.float32).to(device='cuda')
    target = target.type(torch.float32).to(device='cuda')

    with torch.no_grad():
        preds = net(obs)
        val_loss = criterion(preds, target)
        ade += float(utils.ADE_c(preds, target.to('cuda')))
        fde += float(utils.FDE_c(preds, target.to('cuda')))
        aiou += float(utils.AIOU(preds, target.to('cuda')))
        fiou += float(utils.FIOU(preds, target.to('cuda')))

    avg_epoch_val_loss += float(val_loss)

avg_epoch_val_loss/=counter
ade/=counter
fde/=counter     
aiou/=counter
fiou/=counter
print('val_loss: %.4f'% avg_epoch_val_loss, '| ade: %.4f'% ade, '| fde: %.4f'% fde, '| aiou: %.4f'% aiou, '| fiou: %.4f'% fiou)
# Out:
# val_loss: 2116.9175 | ade: 64.3239 | fde: 69.1168 | aiou: 0.2118 | fiou: 0.2076
